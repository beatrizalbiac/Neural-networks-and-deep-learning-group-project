# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizalbiac/Neural-networks-and-deep-learning-group-project/blob/main/notebooks/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git add .
# !git commit -m "Updated train notebook"
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
